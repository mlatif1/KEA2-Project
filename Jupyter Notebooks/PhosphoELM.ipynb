# %%
import numpy as np
import pandas as pd

# %%
#read data from excel file into dataframe 'phospho_df'
phospho_df = pd.read_excel('~/Desktop/phosphoELM_all_2015-04.xlsm')

# %%
#select columns necessary for .gmt format and filter into new dataframe 'df'
df = phospho_df[['acc', 'kinases']]

#drop all columns with an 'NaN' value for the kinases
df.dropna(axis = 0, inplace = True)

#drop duplicate rows in the dataframe
df.drop_duplicates(inplace = True)

#set index of protein values 'acc' as kinases
#creates new dataframe 'kin'
kin = df.set_index('kinases')

#Group kinases in dataframe 'kin'
#Aggregate data in 'kin' according to kinase groups
kin = kin.groupby('kinases').agg(lambda x: tuple(x))

#Create a new column 'PhosphoELM' as description of data
kin.insert(0, 'Description', 'PhosphoELM')

#Create dictionary 'PhosphoELM' with kinases as keys
PhosphoELM = dict([(key, []) for key in kin.index])

#Fill dict with values corresponding to 'PhosphoELM' and relevant proteins
for key in kin.index:
    PhosphoELM[key] = ([['PhosphoELM'], [kin.acc[key]]])
# Out:
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/maayanlab/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# fix the dataframe in order to have three columns:
# kinases, description, acc_merged (acc, but all elements are joined by a \t symbol)
# with a reset index

#create column 'acc_merged' in which all 'acc' elements are joined by a \t symbol
kin['acc_merged'] = ['\t'.join(x) for x in kin['acc']]

#drop the column
kin.drop('acc', axis=1).to_csv('test.txt', sep='\t')

# loop through rows with iteritems
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-01ce38163076> in <module>()
#       8
#       9 #drop the now-unneccesary column 'acc'
# ---> 10 kin.drop('acc', axis=1).to_csv('test.txt', sep='\t')
#      11
#      12 # loop through rows with iteritems
#
# AttributeError: 'list' object has no attribute 'drop'

# %%
with open('text.txt', 'w') as openfile:
    openfile.write('test'+'\n')
    
openfile = open('text.txt', 'w')

openfile.close()

kin.reset_index().head()

for index, rowData in kin.drop('acc', axis=1).reset_index().head().iteritems():
    
    print index, rowData

# %%
import xmltodict
xmltodict.parse(data)

import json
import requests


ENRICHR_URL = 'https://www.ebi.ac.uk/proteins/api/proteins/%s'
protein_id = 'P49757'
response = requests.get(ENRICHR_URL % protein_id)
if not response.ok:
    raise Exception('Error getting protein data from database')
    
data = response.text
print(data)

# %%
#Output file corresponding to GMT-organized dictionary entries as a csv
kin.to_excel('PhosphoELM.xlsm', header = True, index = True)

# %%
#Check that format of the PhosphoELM.csv is correct
pd.read_excel('PhosphoELM.xlsm')
# Out:
#                 kinases  PhosphoELM  \
# 0                  AAK1  PhosphoELM
# 1                   AFK  PhosphoELM
# 2       AKT_group_Caeel  PhosphoELM
# 3                   ALK  PhosphoELM
# 4            AMPK_group  PhosphoELM
# 5                   ATM  PhosphoELM
# 6                   ATR  PhosphoELM
# 7                   Abl  PhosphoELM
# 8                  Abl2  PhosphoELM
# 9             Abl_drome  PhosphoELM
# 10            Ack_drome  PhosphoELM
# 11           Akt1_drome  PhosphoELM
# 12           Atg1_drome  PhosphoELM
# 13             Aurora A  PhosphoELM
# 14             Aurora B  PhosphoELM
# 15                  Axl  PhosphoELM
# 16                BCKDK  PhosphoELM
# 17                  BLK  PhosphoELM
# 18               BMPR1B  PhosphoELM
# 19                  BMX  PhosphoELM
# 20                BRSK1  PhosphoELM
# 21                  BTK  PhosphoELM
# 22                  Brk  PhosphoELM
# 23                CCDPK  PhosphoELM
# 24           CDC2_drome  PhosphoELM
# 25                 CDK1  PhosphoELM
# 26                CDK11  PhosphoELM
# 27                 CDK2  PhosphoELM
# 28                 CDK3  PhosphoELM
# 29                 CDK4  PhosphoELM
# ..                  ...         ...
# 268                TIE2  PhosphoELM
# 269                TLK1  PhosphoELM
# 270                TNK2  PhosphoELM
# 271                TRKA  PhosphoELM
# 272                TRKB  PhosphoELM
# 273               TSSK3  PhosphoELM
# 274                 TTK  PhosphoELM
# 275                 TXK  PhosphoELM
# 276        Titin kinase  PhosphoELM
# 277           Tor_drome  PhosphoELM
# 278  Tropomyosin kinase  PhosphoELM
# 279                Tyk2  PhosphoELM
# 280                VRK1  PhosphoELM
# 281                WEE1  PhosphoELM
# 282                WNK1  PhosphoELM
# 283                 Yes  PhosphoELM
# 284               ZAP70  PhosphoELM
# 285            fu_drome  PhosphoELM
# 286           hop_drome  PhosphoELM
# 287         lit-1_Caeel  PhosphoELM
# 288                mTOR  PhosphoELM
# 289    mapk_group_drome  PhosphoELM
# 290         mbk-2_Caeel  PhosphoELM
# 291           p38_group  PhosphoELM
# 292              p70S6K  PhosphoELM
# 293        p70S6K_group  PhosphoELM
# 294             p70S6Kb  PhosphoELM
# 295           sgg_drome  PhosphoELM
# 296        unc-43_Caeel  PhosphoELM
# 297           wts_drome  PhosphoELM
#
#                                                    acc
# 0                       ('P49757', 'Q9BXS5', 'Q96CW1')
# 1                                          ('P02576',)
# 2                                        ('C50F4.11',)
# 3                       ('P40763', 'Q9UM73', 'Q86WB0')
# 4    ('P07248', 'P11497', 'P15304', 'P16386', 'P186...
# 5    ('O96017', 'P00519', 'P04637', 'P15336', 'P159...
# 6    ('P16220', 'P38398', 'Q00987', 'Q01094', 'O147...
# 7    ('O15162', 'O15350', 'P00519', 'P00520', 'P040...
# 8             ('P04040', 'O15304', 'Q9JIA3', 'P07203')
# 9                                          ('P55162',)
# 10                                      ('CG6757-PA',)
# 11                                      ('CG6975-PA',)
# 12                                      ('CG3981-PB',)
# 13   ('P04637', 'P68431', 'P30305', 'P38398', 'O149...
# 14   ('O15392', 'P08670', 'P68431', 'P20152', 'P842...
# 15                                         ('P30530',)
# 16                                         ('P11960',)
# 17                                ('P12318', 'P31994')
# 18                                ('Q15796', 'Q15797')
# 19                                         ('Q96T51',)
# 20                                ('P30305', 'P30307')
# 21   ('P42768', 'Q06187', 'P78347', 'P24135', 'P168...
# 22                                ('P49023', 'Q13882')
# 23                      ('P06782', 'P26678', 'P35270')
# 24                                ('P08928', 'P20240')
# 25   ('O15392', 'P00533', 'P04183', 'P05787', 'P067...
# 26                                         ('O00303',)
# 27   ('O15350', 'P04183', 'P06401', 'P38398', 'P389...
# 28                                         ('P18846',)
# 29   ('P28749', 'Q08999', 'P17480', 'P53566', 'P840...
# ..                                                 ...
# 268                               ('Q02763', 'Q02858')
# 269                                        ('Q99638',)
# 270                                        ('Q07912',)
# 271                                        ('P04629',)
# 272                     ('P15209', 'Q91WJ0', 'Q60610')
# 273                                        ('Q9D2E1',)
# 274  ('O96017', 'P00519', 'P04637', 'Q53HL2', 'P386...
# 275                     ('Q13094', 'P16410', 'P42681')
# 276                               ('O15273', 'O70548')
# 277                           ('P18475', 'CG10539-PA')
# 278                               ('P58771', 'P58776')
# 279  ('P17181', 'P29597', 'P63244', 'Q13651', 'O090...
# 280           ('P04637', 'P05412', 'P15336', 'P68431')
# 281                                        ('P06493',)
# 282                     ('O95747', 'Q9UEW8', 'P46097')
# 283           ('P22681', 'P07947', 'Q04736', 'Q91GT2')
# 284  ('P29353', 'Q13094', 'Q16539', 'Q9UQC2', 'O549...
# 285                                     ('CG1708-PA',)
# 286                                        ('Q24151',)
# 287                                        ('Q10666',)
# 288  ('P23443', 'P42345', 'Q13541', 'Q9UBS0', 'P317...
# 289                               ('P22813', 'Q01842')
# 290                                     ('C09G9.6.1',)
# 291                               ('P35638', 'Q9UBK2')
# 292  ('P62753', 'P23443', 'P42345', 'P23588', 'Q9BY...
# 293                     ('P62753', 'P48678', 'O00418')
# 294                               ('P04792', 'P05783')
# 295                                        ('P19538',)
# 296                                        ('Q95V25',)
# 297                                     ('CG4005-PB',)
#
# [298 rows x 3 columns]
